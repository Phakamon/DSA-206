# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Fdata =  pd.read_csv("fishdata2.csv",encoding= 'unicode_escape')
Fdata
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3170: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           2020     6  18  14    30    33  \
# 0       2020.0   6.0  18  14  30.0  43.0
# 1       2020.0   6.0  18  14  30.0  48.0
# 2       2020.0   6.0  18  14  31.0   3.0
# 3       2020.0   6.0  18  14  31.0   8.0
# 4       2020.0   6.0  18  14  31.0  13.0
# ...        ...   ...  ..  ..   ...   ...
# 811941  2020.0  10.0  19   8  24.0   4.0
# 811942  2020.0  10.0  19   8  24.0   8.0
# 811943  2020.0  10.0  19   8  24.0  13.0
# 811944  2020.0  10.0  19   8  24.0  16.0
# 811945  2020.0  10.0  19   8  24.0  20.0
#
#        qCBrs9¥ R! Â¤cäÍFóInitializing.... Please Wait!  Unnamed: 7  \
# 0                                                     201        25.0
# 1                                                     201        25.0
# ...

# %%
Fdata.rename(columns={'2020':'Year', '6':'Month', '18':'Day', '14':'Hour', '30':'Minute', '33':'Second',
       'qCBrs9¥ R! Â¤cäÍFóInitializing.... Please Wait!':'Carbonmonoxide', 'Unnamed: 7':'PM2.5',
       'Unnamed: 8':'External_Temp', 'Unnamed: 9':'Humidity', 'Unnamed: 10':'Internal_Temp', 'Unnamed: 11':'Ignore'
},inplace = True)
Fdata
# Out:
#           Year  Month  Day  Hour  Minute  Second Carbonmonoxide  PM2.5  \
# 0       2020.0    6.0   18    14    30.0    43.0            201   25.0
# 1       2020.0    6.0   18    14    30.0    48.0            201   25.0
# 2       2020.0    6.0   18    14    31.0     3.0            201   25.0
# 3       2020.0    6.0   18    14    31.0     8.0            201   25.0
# 4       2020.0    6.0   18    14    31.0    13.0            201   25.0
# ...        ...    ...  ...   ...     ...     ...            ...    ...
# 811941  2020.0   10.0   19     8    24.0     4.0            201 -165.0
# 811942  2020.0   10.0   19     8    24.0     8.0            201 -167.0
# 811943  2020.0   10.0   19     8    24.0    13.0           -168   25.0
# 811944  2020.0   10.0   19     8    24.0    16.0            201 -169.0
# 811945  2020.0   10.0   19     8    24.0    20.0            201 -169.0
#
#         External_Temp  Humidity  Internal_Temp  Ignore
# 0                29.0     95.00          27.19    4.39
# ...

# %%
Fdata.head(5)
# Out:
#      Year  Month  Day  Hour  Minute  Second Carbonmonoxide  PM2.5  \
# 0  2020.0    6.0   18    14    30.0    43.0            201   25.0
# 1  2020.0    6.0   18    14    30.0    48.0            201   25.0
# 2  2020.0    6.0   18    14    31.0     3.0            201   25.0
# 3  2020.0    6.0   18    14    31.0     8.0            201   25.0
# 4  2020.0    6.0   18    14    31.0    13.0            201   25.0
#
#    External_Temp  Humidity  Internal_Temp  Ignore
# 0           29.0      95.0          27.19    4.39
# 1           29.0      95.0          27.19    4.38
# 2           29.0      95.0          27.19    4.38
# 3           29.0      95.0          27.19    4.41
# 4           29.0      95.0          27.25    4.41

# %%
Fdata.dtypes
# Out:
# Year              float64
# Month             float64
# Day                 int64
# Hour                int64
# Minute            float64
# Second            float64
# Carbonmonoxide     object
# PM2.5             float64
# External_Temp     float64
# Humidity          float64
# Internal_Temp     float64
# Ignore            float64
# dtype: object

# %%
#Change data types
#Fdata['Carbonmonoxide'] = Fdata['Carbonmonoxide'].astype(float)
Fdata[['Carbonmonoxide' ]] = Fdata[['Carbonmonoxide']].apply(pd.to_numeric, errors = 'coerce')

# %%
Fdata.dtypes
# Out:
# Year              float64
# Month             float64
# Day                 int64
# Hour                int64
# Minute            float64
# Second            float64
# Carbonmonoxide    float64
# PM2.5             float64
# External_Temp     float64
# Humidity          float64
# Internal_Temp     float64
# Ignore            float64
# dtype: object

# %%
Fdata.isnull().sum()
# Out:
# Year                 0
# Month                0
# Day                  0
# Hour                 0
# Minute               0
# Second               0
# Carbonmonoxide    1751
# PM2.5               74
# External_Temp       95
# Humidity           103
# Internal_Temp      103
# Ignore            4538
# dtype: int64

# %%
Fdata.shape
# Out:
# (811946, 12)

# %%
Fdata.dropna(subset = ['Carbonmonoxide','PM2.5','PM2.5','External_Temp','Humidity','Internal_Temp','Ignore'] , inplace = True)
Fdata.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Hour              0
# Minute            0
# Second            0
# Carbonmonoxide    0
# PM2.5             0
# External_Temp     0
# Humidity          0
# Internal_Temp     0
# Ignore            0
# dtype: int64

# %%
Fdata.shape
# Out:
# (805729, 12)

# %%
Fdata
# Out:
#           Year  Month  Day  Hour  Minute  Second  Carbonmonoxide  PM2.5  \
# 0       2020.0    6.0   18    14    30.0    43.0           201.0   25.0
# 1       2020.0    6.0   18    14    30.0    48.0           201.0   25.0
# 2       2020.0    6.0   18    14    31.0     3.0           201.0   25.0
# 3       2020.0    6.0   18    14    31.0     8.0           201.0   25.0
# 4       2020.0    6.0   18    14    31.0    13.0           201.0   25.0
# ...        ...    ...  ...   ...     ...     ...             ...    ...
# 811940  2020.0   10.0   19     8    24.0     0.0           201.0 -165.0
# 811941  2020.0   10.0   19     8    24.0     4.0           201.0 -165.0
# 811942  2020.0   10.0   19     8    24.0     8.0           201.0 -167.0
# 811944  2020.0   10.0   19     8    24.0    16.0           201.0 -169.0
# 811945  2020.0   10.0   19     8    24.0    20.0           201.0 -169.0
#
#         External_Temp  Humidity  Internal_Temp  Ignore
# ...

# %%
Fdata.mean()
# Out:
# Year              2038.125980
# Month                2.580095
# Day                 18.485705
# Hour                11.778356
# Minute              29.475378
# Second              29.499549
# Carbonmonoxide     213.713183
# PM2.5              -65.525206
# External_Temp       30.474023
# Humidity            94.992290
# Internal_Temp       28.621689
# Ignore              82.909025
# dtype: float64

# %%
Fdata.drop(Fdata[Fdata['Year'] > 2020.0].index, inplace = True)

# %%
Fdata.mean()
# Out:
# Year              2019.894042
# Month                2.580052
# Day                 18.485746
# Hour                11.778391
# Minute              29.475355
# Second              29.499625
# Carbonmonoxide     213.712436
# PM2.5              -65.525273
# External_Temp       30.474026
# Humidity            94.992290
# Internal_Temp       28.621683
# Ignore              82.909899
# dtype: float64

# %%
#Histogram
plt.hist(Fdata['External_Temp'],
        density=True, facecolor='g', alpha=0.6)
plt.axis([-100,50,0,0.01])
plt.show()
